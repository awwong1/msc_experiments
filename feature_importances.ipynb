# %% [markdown]
# # Analyze top feature importances and train smaller models
#
# * `full_output` : XGB all manually extracted features
# * `full_output-with_embedding`: XGB all manually extracted features WITH autoencoder embeddings

# %%
import json
import pickle
from glob import glob
import pandas as pd

import numpy as np
import xgboost
from utils import ElapsedTimer

# %%
# Load the SNOMED_CT Mapping to DX
with open("data/snomed_ct_dx_map.json", "r") as f:
    SNOMED_CODE_MAP = json.load(f)

# %%
print("Loading features...")
with ElapsedTimer() as t:
    features = pd.read_csv("full_output/features.csv", index_col="header_file")
    features.sort_values(by=["header_file"], inplace=True)
    # features
print(f"Took {t.duration:.2f}s")
# Out:
# Loading features...
# Took 444.94s

# %%
raw_model_paths = glob("full_output/*.pkl")

for raw_model_path in raw_model_paths:
    with open(raw_model_paths[0], "rb") as f:
        m = pickle.load(f)

    print(raw_model_path)
    print(raw_model_path.split("_models.pkl")[0])
    for key in m.keys():
        print(SNOMED_CODE_MAP[key])
        xgb_classifier = m[key]
        print(xgb_classifier.feature_importances_)
        sorted_feat_idxs = xgb_classifier.feature_importances_.argsort()
        print(sorted_feat_idxs) # ascending order, so 0 is worst

        top_100 = sorted_feat_idxs[::-1][:100]
        # print(xgb_classifier.feature_importances_[top_100])
        print(top_100)
        
        # print(features.columns[top_100])
        labels = list(features.columns[top_100])
        # print(labels)
        # top 100 dataframe features
        print(features.iloc[:, top_100])
        break

    break
# Out:
# full_output/v17_models.pkl
# full_output/v17
# ['IAVB', '1st degree av block']
# [1.3748114e-03 3.7994151e-04 5.2086471e-05 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00]
# [ 9474 11977 11978 ... 15794  4746     4]
# [    4  4746 15794   926  4741  5667   925  5663   437 12641 14238   745
#      7 10078 15792 17374  9481  7061  5252 11991 10067  2074  2027 10982
#  10401 13031  5107   391  9922  1586  5563 16558 12634  2061 11151 11048
#  10398  7242 11073  9482  2127 12792  4040  2105  8039  3178  5041 17378
#   7904  3160  5024 17384  2005 14240  6340 17371 11061 10133 10044     0
#   9744 17961  8164 11058  7902 10156 14219 10233  2216  8288 18484  1606
#   9527 10552 10405  8521 14770  9743 14225 10066 18252  5566 11100 10372
#   8310 17383 12643  5130  9614  2194 10357  2518  1849 10682  2016 10407
#  15801 12647 11165   499]
# ['I_HRV_MeanNN', 'aVR_HRV_MedianNN', 'V5_HRV_MeanNN', 'I_sig__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2', 'aVR_HRV_MeanNN', 'aVR_sig__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2', 'I_sig__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.0', 'aVR_sig__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2', 'I_hb__fft_coefficient__attr_"angle"__coeff_6', 'V3_HRV_MedianNN', 'V4_HRV_SD2', 'I_hb__number_peaks__n_50', 'I_HRV_CVNN', 'V1_hb__fft_coefficient__attr_"real"__coeff_3', 'V5_ECG_Rate_Mean', 'V6_HRV_SDNN', 'V1_HRV_CVNN', 'aVL_hb__number_peaks__n_50', 'aVR_hb__fft_coefficient__attr_"imag"__coeff_4', 'V2_sig__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.2', 'V1_hb__fft_coefficient__attr_"real"__coeff_2', 'II_hb__fft_coefficient__attr_"imag"__coeff_21', 'II_hb__fft_coefficient__attr_"angle"__coeff_7', 'V1_sig__number_peaks__n_50', 'V1_sig__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.4', 'V3_hb__fft_coefficient__attr_"angle"__coeff_25', 'aVR_hb__fft_coefficient__attr_"abs"__coeff_9', 'I_hb__fft_coefficient__attr_"angle"__coeff_18', 'V1_hb__fft_coefficient__attr_"angle"__coeff_7', 'II_HRV_CVNN', 'aVR_sig__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"', 'V5_hb__range_count__max_1__min_-1', 'V3_ECG_Rate_Mean', 'II_hb__fft_coefficient__attr_"imag"__coeff_1', 'V2_hb__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"min"', 'V1_sig__time_reversal_asymmetry_statistic__lag_3', 'V1_sig__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.4', 'aVL_sig__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2', 'V2_HRV_HF', 'V1_HRV_CVSD', 'II_hb__fft_coefficient__attr_"imag"__coeff_7', 'V3_hb__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.2', 'III_sig__ar_coefficient__coeff_5__k_10', 'II_hb__fft_coefficient__attr_"imag"__coeff_5', 'aVF_hb__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.0', 'III_HRV_HF', 'aVR_hb__fft_coefficient__attr_"abs"__coeff_3', 'V6_HRV_MedianNN', 'aVF_HRV_MedianNN', 'III_ECG_Rate_Mean', 'aVR_hb__fft_coefficient__attr_"abs"__coeff_14', 'V6_HRV_TINN', 'II_hb__fft_coefficient__attr_"angle"__coeff_5', 'V4_HRV_S', 'aVL_HRV_HFn', 'V6_ECG_Rate_Mean', 'V2_HRV_CVSD', 'V1_hb__fft_coefficient__attr_"real"__coeff_8', 'V1_hb__fft_coefficient__attr_"imag"__coeff_9', 'age', 'V1_hb__energy_ratio_by_chunks__num_segments_10__segment_focus_3', 'V6_hb__fft_coefficient__attr_"real"__coeff_19', 'aVF_hb__energy_ratio_by_chunks__num_segments_10__segment_focus_2', 'V2_HRV_SDNN', 'aVF_HRV_CVNN', 'V1_hb__first_location_of_minimum', 'V4_HRV_CVSD', 'V1_hb__quantile__q_0.2', 'II_hb__fft_coefficient__attr_"real"__coeff_6', 'aVF_hb__fft_coefficient__attr_"angle"__coeff_2', 'V6_sig__fft_coefficient__attr_"abs"__coeff_73', 'II_HRV_SD2', 'V1_HRV_ApEn', 'V1_sig__fft_coefficient__attr_"abs"__coeff_4', 'V1_sig__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.4', 'aVF_hb__fft_coefficient__attr_"real"__coeff_5', 'V4_hb__fft_coefficient__attr_"imag"__coeff_8', 'V1_hb__energy_ratio_by_chunks__num_segments_10__segment_focus_2', 'V4_HRV_pNN20', 'V1_hb__fft_coefficient__attr_"real"__coeff_19', 'V6_sig__ar_coefficient__coeff_6__k_10', 'aVR_sig__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"min"', 'V2_HRV_SD2d', 'V1_sig__autocorrelation__lag_8', 'aVF_hb__fft_coefficient__attr_"angle"__coeff_4', 'V6_HRV_pNN20', 'V3_HRV_MCVNN', 'aVR_hb__fft_coefficient__attr_"angle"__coeff_2', 'V1_hb__c3__lag_3', 'II_hb__fft_coefficient__attr_"real"__coeff_4', 'V1_sig__ar_coefficient__coeff_6__k_10', 'II_sig__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.4', 'II_hb__energy_ratio_by_chunks__num_segments_10__segment_focus_3', 'V1_sig__fft_coefficient__attr_"angle"__coeff_67', 'II_hb__fft_coefficient__attr_"angle"__coeff_6', 'V1_sig__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.8', 'V5_HRV_MCVNN', 'V3_HRV_TINN', 'V2_hb__approximate_entropy__m_2__r_0.9', 'I_hb__fft_coefficient__attr_"imag"__coeff_25']
#                            I_HRV_MeanNN  aVR_HRV_MedianNN  V5_HRV_MeanNN  \
# header_file
# data/Training_2/Q0001.hea    584.400000             584.0     584.533333
# data/Training_2/Q0002.hea    860.375000             863.0     860.375000
# data/Training_2/Q0003.hea    649.529412             650.0     649.647059
# data/Training_2/Q0004.hea    715.538462             714.0     715.538462
# data/Training_2/Q0005.hea    809.192982             808.0     809.192982
# ...                                 ...               ...            ...
# data/WFDB/S0545.hea          615.005181             563.0     586.251232
# data/WFDB/S0546.hea          538.547511             560.0     536.121622
# data/WFDB/S0547.hea          811.198630             809.0     774.084967
# data/WFDB/S0548.hea          834.563380             835.0     834.563380
# data/WFDB/S0549.hea          804.932432             802.0     804.932432
#
#                            I_sig__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2  \
# header_file
# data/Training_2/Q0001.hea                                           0.001743
# data/Training_2/Q0002.hea                                           0.001359
# data/Training_2/Q0003.hea                                           0.002256
# data/Training_2/Q0004.hea                                           0.000542
# data/Training_2/Q0005.hea                                           0.001163
# ...                                                                      ...
# data/WFDB/S0545.hea                                                 0.015576
# data/WFDB/S0546.hea                                                 0.003073
# data/WFDB/S0547.hea                                                 0.001876
# data/WFDB/S0548.hea                                                 0.001055
# data/WFDB/S0549.hea                                                 0.002183
#
#                            aVR_HRV_MeanNN  \
# header_file
# data/Training_2/Q0001.hea      584.400000
# data/Training_2/Q0002.hea      859.875000
# data/Training_2/Q0003.hea      649.529412
# data/Training_2/Q0004.hea      715.538462
# data/Training_2/Q0005.hea      796.551724
# ...                                   ...
# data/WFDB/S0545.hea            550.476852
# data/WFDB/S0546.hea            545.940367
# data/WFDB/S0547.hea            778.940789
# data/WFDB/S0548.hea            834.577465
# data/WFDB/S0549.hea            804.938776
#
#                            aVR_sig__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2  \
# header_file
# data/Training_2/Q0001.hea                                           0.003145
# data/Training_2/Q0002.hea                                           0.001693
# data/Training_2/Q0003.hea                                           0.001155
# data/Training_2/Q0004.hea                                           0.002447
# data/Training_2/Q0005.hea                                           0.001515
# ...                                                                      ...
# data/WFDB/S0545.hea                                                 0.008408
# data/WFDB/S0546.hea                                                 0.003153
# data/WFDB/S0547.hea                                                 0.003811
# data/WFDB/S0548.hea                                                 0.001301
# data/WFDB/S0549.hea                                                 0.001487
#
#                            I_sig__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.0  \
# header_file
# data/Training_2/Q0001.hea                                           0.003360
# data/Training_2/Q0002.hea                                           0.002009
# data/Training_2/Q0003.hea                                           0.001950
# data/Training_2/Q0004.hea                                           0.001479
# data/Training_2/Q0005.hea                                           0.001638
# ...                                                                      ...
# data/WFDB/S0545.hea                                                 0.014856
# data/WFDB/S0546.hea                                                 0.004145
# data/WFDB/S0547.hea                                                 0.002622
# data/WFDB/S0548.hea                                                 0.001641
# data/WFDB/S0549.hea                                                 0.001989
#
#                            aVR_sig__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2  \
# header_file
# data/Training_2/Q0001.hea                                           0.001825
# data/Training_2/Q0002.hea                                           0.001504
# data/Training_2/Q0003.hea                                           0.001177
# data/Training_2/Q0004.hea                                           0.001292
# data/Training_2/Q0005.hea                                           0.001333
# ...                                                                      ...
# data/WFDB/S0545.hea                                                 0.008988
# data/WFDB/S0546.hea                                                 0.002729
# data/WFDB/S0547.hea                                                 0.002302
# data/WFDB/S0548.hea                                                 0.001051
# data/WFDB/S0549.hea                                                 0.001272
#
#                            I_hb__fft_coefficient__attr_"angle"__coeff_6  \
# header_file
# data/Training_2/Q0001.hea                                    129.813255
# data/Training_2/Q0002.hea                                    113.372889
# data/Training_2/Q0003.hea                                    -31.621119
# data/Training_2/Q0004.hea                                    108.955582
# data/Training_2/Q0005.hea                                    112.747379
# ...                                                                 ...
# data/WFDB/S0545.hea                                          117.098617
# data/WFDB/S0546.hea                                          119.525228
# data/WFDB/S0547.hea                                          -46.769401
# data/WFDB/S0548.hea                                         -169.836718
# data/WFDB/S0549.hea                                         -178.114102
#
#                            V3_HRV_MedianNN  ...  \
# header_file                                 ...
# data/Training_2/Q0001.hea            584.0  ...
# data/Training_2/Q0002.hea            862.0  ...
# data/Training_2/Q0003.hea            650.0  ...
# data/Training_2/Q0004.hea            714.0  ...
# data/Training_2/Q0005.hea            810.0  ...
# ...                                    ...  ...
# data/WFDB/S0545.hea                  565.0  ...
# data/WFDB/S0546.hea                  560.0  ...
# data/WFDB/S0547.hea                  810.0  ...
# data/WFDB/S0548.hea                  842.0  ...
# data/WFDB/S0549.hea                  802.0  ...
#
#                            V1_sig__ar_coefficient__coeff_6__k_10  \
# header_file
# data/Training_2/Q0001.hea                              -0.613273
# data/Training_2/Q0002.hea                              -0.277672
# data/Training_2/Q0003.hea                              -0.510542
# data/Training_2/Q0004.hea                              -2.088981
# data/Training_2/Q0005.hea                              -1.673595
# ...                                                          ...
# data/WFDB/S0545.hea                                    -0.195073
# data/WFDB/S0546.hea                                    -0.825181
# data/WFDB/S0547.hea                                    -0.725497
# data/WFDB/S0548.hea                                     0.855650
# data/WFDB/S0549.hea                                    -0.376996
#
#                            II_sig__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.4  \
# header_file
# data/Training_2/Q0001.hea                                       3.878035e-06
# data/Training_2/Q0002.hea                                       5.006327e-06
# data/Training_2/Q0003.hea                                       1.358932e-06
# data/Training_2/Q0004.hea                                       3.432108e-06
# data/Training_2/Q0005.hea                                       1.707957e-06
# ...                                                                      ...
# data/WFDB/S0545.hea                                             1.059298e-05
# data/WFDB/S0546.hea                                             1.027594e-05
# data/WFDB/S0547.hea                                             1.459952e-05
# data/WFDB/S0548.hea                                             3.116498e-06
# data/WFDB/S0549.hea                                             7.933167e-07
#
#                            II_hb__energy_ratio_by_chunks__num_segments_10__segment_focus_3  \
# header_file
# data/Training_2/Q0001.hea                                           0.067875
# data/Training_2/Q0002.hea                                           0.056942
# data/Training_2/Q0003.hea                                           0.079388
# data/Training_2/Q0004.hea                                           0.064294
# data/Training_2/Q0005.hea                                           0.054484
# ...                                                                      ...
# data/WFDB/S0545.hea                                                 0.026289
# data/WFDB/S0546.hea                                                 0.021875
# data/WFDB/S0547.hea                                                 0.286969
# data/WFDB/S0548.hea                                                 0.153177
# data/WFDB/S0549.hea                                                 0.218274
#
#                            V1_sig__fft_coefficient__attr_"angle"__coeff_67  \
# header_file
# data/Training_2/Q0001.hea                                       -15.604141
# data/Training_2/Q0002.hea                                       -55.812683
# data/Training_2/Q0003.hea                                        62.853690
# data/Training_2/Q0004.hea                                       143.364142
# data/Training_2/Q0005.hea                                        -6.631973
# ...                                                                    ...
# data/WFDB/S0545.hea                                             -50.408955
# data/WFDB/S0546.hea                                             -15.565044
# data/WFDB/S0547.hea                                             -18.705422
# data/WFDB/S0548.hea                                              35.832502
# data/WFDB/S0549.hea                                             -41.799350
#
#                            II_hb__fft_coefficient__attr_"angle"__coeff_6  \
# header_file
# data/Training_2/Q0001.hea                                     132.891166
# data/Training_2/Q0002.hea                                      95.610565
# data/Training_2/Q0003.hea                                      96.764932
# data/Training_2/Q0004.hea                                      83.918041
# data/Training_2/Q0005.hea                                      96.573039
# ...                                                                  ...
# data/WFDB/S0545.hea                                           175.766824
# data/WFDB/S0546.hea                                           161.480076
# data/WFDB/S0547.hea                                          -147.734930
# data/WFDB/S0548.hea                                          -170.747236
# data/WFDB/S0549.hea                                           178.368782
#
#                            V1_sig__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.8  \
# header_file
# data/Training_2/Q0001.hea                                           0.001652
# data/Training_2/Q0002.hea                                           0.001283
# data/Training_2/Q0003.hea                                           0.005102
# data/Training_2/Q0004.hea                                           0.007853
# data/Training_2/Q0005.hea                                           0.001773
# ...                                                                      ...
# data/WFDB/S0545.hea                                                 0.003663
# data/WFDB/S0546.hea                                                 0.002332
# data/WFDB/S0547.hea                                                 0.003385
# data/WFDB/S0548.hea                                                 0.002665
# data/WFDB/S0549.hea                                                 0.002780
#
#                            V5_HRV_MCVNN  V3_HRV_TINN  \
# header_file
# data/Training_2/Q0001.hea      0.005077        592.0
# data/Training_2/Q0002.hea      0.006880         20.0
# data/Training_2/Q0003.hea      0.009124         20.0
# data/Training_2/Q0004.hea      0.024918        104.0
# data/Training_2/Q0005.hea      0.043929        170.0
# ...                                 ...          ...
# data/WFDB/S0545.hea            0.112636       1144.0
# data/WFDB/S0546.hea            0.013214        401.0
# data/WFDB/S0547.hea            0.014625       4847.0
# data/WFDB/S0548.hea            0.013309       4975.0
# data/WFDB/S0549.hea            0.012940         67.0
#
#                            V2_hb__approximate_entropy__m_2__r_0.9  \
# header_file
# data/Training_2/Q0001.hea                                0.027428
# data/Training_2/Q0002.hea                                0.046755
# data/Training_2/Q0003.hea                                0.061932
# data/Training_2/Q0004.hea                                0.066817
# data/Training_2/Q0005.hea                                0.032395
# ...                                                           ...
# data/WFDB/S0545.hea                                      0.027751
# data/WFDB/S0546.hea                                      0.016521
# data/WFDB/S0547.hea                                      0.021230
# data/WFDB/S0548.hea                                      0.018498
# data/WFDB/S0549.hea                                      0.021403
#
#                            I_hb__fft_coefficient__attr_"imag"__coeff_25
# header_file
# data/Training_2/Q0001.hea                                     -0.148830
# data/Training_2/Q0002.hea                                     -0.557004
# data/Training_2/Q0003.hea                                     -0.970614
# data/Training_2/Q0004.hea                                     -1.595130
# data/Training_2/Q0005.hea                                     -1.362850
# ...                                                                 ...
# data/WFDB/S0545.hea                                            1.361933
# data/WFDB/S0546.hea                                            0.959655
# data/WFDB/S0547.hea                                           -0.480332
# data/WFDB/S0548.hea                                           -0.257767
# data/WFDB/S0549.hea                                           -0.410268
#
# [43099 rows x 100 columns]

# %%
# Out:
# (18950,)

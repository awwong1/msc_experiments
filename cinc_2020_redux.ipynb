# %% [markdown]
# # Replicate CinC2020 Methodology for comparison

# %%
import os
import json
import pickle
from glob import glob

import torch
import numpy as np
import pandas as pd
from xgboost import XGBClassifier
import zarr

from utils import ElapsedTimer
from utils.evaluation_helper import evaluate_score_batch
from utils.evaluate_12ECG_score import load_table

# %%
experiment_dir = "full_output"
print(experiment_dir)
# Out:
# full_output

# %%
print("Loading features...")
with ElapsedTimer() as t:
    features = pd.read_csv(
        os.path.join(experiment_dir, "features.csv"), index_col="header_file"
    )
    features.sort_values(by=["header_file"], inplace=True)
    # features
    print(f"Took {t.duration:.2f}s")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-188479872c65> in <module>
#       1 # features = pd.read_csv("cinc-2020-redux/features.csv", index_col="header_file")
# ----> 2 features = pd.read_csv("full_output/features.csv", index_col="header_file")
#       3 features.sort_values(by=["header_file"], inplace=True)
#       4 features
#
# /media/pea/msc_experiments/venv/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /media/pea/msc_experiments/venv/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     458
#     459     try:
# --> 460         data = parser.read(nrows)
#     461     finally:
#     462         parser.close()
#
# /media/pea/msc_experiments/venv/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1196     def read(self, nrows=None):
#    1197         nrows = _validate_integer("nrows", nrows)
# -> 1198         ret = self._engine.read(nrows)
#    1199
#    1200         # May alter columns / col_dict
#
# /media/pea/msc_experiments/venv/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2155     def read(self, nrows=None):
#    2156         try:
# -> 2157             data = self._reader.read(nrows)
#    2158         except StopIteration:
#    2159             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# /media/pea/msc_experiments/venv/lib/python3.8/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     528
#     529
# --> 530 def is_categorical_dtype(arr_or_dtype) -> bool:
#     531     """
#     532     Check whether an array-like or dtype is of the Categorical dtype.
#
# KeyboardInterrupt:

# %%
dxs = {}
print("Loading labels...")
with open(os.path.join(experiment_dir, "dxs.txt")) as f:
    for line in f.readlines():
        k, v = json.loads(line)
        dxs[k] = v
# Out:
# Loading labels...

# %%
with open("data/snomed_ct_dx_map.json", "r") as f:
    SNOMED_CODE_MAP = json.load(f)
# SNOMED_CODE_MAP

# %%
root = zarr.open_group("data/ecgs.zarr", mode="r")
root.info

# check dxs match!
for idx, file_path in enumerate(features.iloc[:100].index.to_list()):
    assert list(root["raw/dx"][idx]) == dxs[file_path], idx

# %%
weights_file = "evaluation-2020/weights.csv"
rows, cols, all_weights = load_table(weights_file)
assert rows == cols
scored_codes = rows
# scored_codes

# %% [markdown]
# ## Load same training/validation/test splits

# %%
torch_checkpoints = glob("log_beat_autoencoder/*/checkpoints/*.ckpt")
data_configs = []
for torch_checkpoint in torch_checkpoints:
    state_dict = torch.load(torch_checkpoint)
    raw_data_config = state_dict["hyper_parameters"]["data_config"]
    
    data_config = {}
    for k, v in raw_data_config.items():
        data_config[k] = v.indices
    data_configs.append(data_config)

    # data_configs.append(data_config)

len(data_configs)
# Out:
# 20

# %%
data_configs[0].keys()
# Out:
# dict_keys(['train_records', 'val_records', 'test_records'])

# %% [markdown]
# ### Train Classifiers per label

# %%
def _determine_sample_weights(
    data_set, scored_codes, label_weights, weight_threshold=0.5
):
    """Using the scoring labels weights to increase the dataset size of positive labels
    """
    data_labels = []
    sample_weights = []
    for dt in data_set:
        sample_weight = None
        for dx in dt:
            if str(dx) in scored_codes:
                _sample_weight = label_weights[scored_codes.index(str(dx))]
                if _sample_weight < weight_threshold:
                    continue
                if sample_weight is None or _sample_weight > sample_weight:
                    sample_weight = _sample_weight

        if sample_weight is None:
            # not a scored label, treat as a negative example (weight of 1)
            sample_weight = 1.0
            data_labels.append(False)
        else:
            data_labels.append(True)
        sample_weights.append(sample_weight)
    return data_labels, sample_weights


def _train_label_classifier(
    sc,
    idx_sc,
    all_weights,
    train_features,
    train_labels,
    eval_features,
    eval_labels,
    scored_codes,
    early_stopping_rounds,
    num_gpus,
):
    label_weights = all_weights[idx_sc]
    train_labels, train_weights = _determine_sample_weights(
        train_labels, scored_codes, label_weights
    )
    eval_labels, eval_weights = _determine_sample_weights(
        eval_labels, scored_codes, label_weights
    )

    # try negative over positive https://machinelearningmastery.com/xgboost-for-imbalanced-classification/
    pos_count = len([e for e in train_labels if e])
    pos_count = max(pos_count, 1)
    scale_pos_weight = (len(train_labels) - pos_count) / pos_count

    model = XGBClassifier(
        booster="dart",  # gbtree, dart or gblinear
        verbosity=0,
        tree_method = "gpu_hist",
        sampling_method = "gradient_based",
        scale_pos_weight=scale_pos_weight,
    )

    eval_set = [
        (train_features, train_labels), (eval_features, eval_labels)
    ]
    sample_weight_eval_set = [
        train_weights, eval_weights
    ]

    model = model.fit(
        train_features,
        train_labels,
        sample_weight=train_weights,
        eval_set=eval_set,
        sample_weight_eval_set=sample_weight_eval_set,
        early_stopping_rounds=early_stopping_rounds,
        verbose=False,
    )

    return sc, model

def train_experiment(
    data_config,
    all_weights=all_weights,
    scored_codes=scored_codes,
    features=features,
    root=root,
    early_stopping_rounds=20,
    
):
    train_idxs = data_config["train_records"]
    val_idxs = data_config["val_records"]
    test_idxs = data_config["test_records"]
    
    train_features, train_labels = features.take(train_idxs), np.take(root["raw/dx"], train_idxs)
    eval_features, eval_labels = features.take(val_idxs), np.take(root["raw/dx"], val_idxs)
    test_features, test_labels = features.take(test_idxs), np.take(root["raw/dx"], test_idxs)

    classes = []
    labels = []
    scores = []
    
    models = {}
    
    for idx_sc, sc in enumerate(scored_codes):
        with ElapsedTimer() as t:
            print(f"Training {SNOMED_CODE_MAP[sc][1]} classifier...", end="")
            sc, model = _train_label_classifier(
                sc,
                idx_sc,
                all_weights,
                train_features,
                train_labels,
                eval_features,
                eval_labels,
                scored_codes,
                early_stopping_rounds,
                1,
            )
            classes.append(str(sc))
            labels.append(model.predict(test_features).tolist())
            scores.append(model.predict_proba(test_features)[:, 1].tolist())
            models[sc] = model
        print(f"Took {t.duration:.2f} seconds")

    (
        classes,
        auroc,
        auprc,
        auroc_classes,
        auprc_classes,
        accuracy,
        f_measure,
        f_measure_classes,
        f_beta_measure,
        g_beta_measure,
        challenge_metric,
    ) = evaluate_score_batch(
        predicted_classes=classes,
        predicted_labels=np.array(labels).T,
        predicted_probabilities=np.array(scores).T,
        raw_ground_truth_labels=test_labels,
    )
        
    log = {
        "test_auroc": auroc,
        "test_auprc": auprc,
        "test_accuracy": accuracy,
        "test_f_measure": f_measure,
        "test_f_beta_measure": f_beta_measure,
        "test_g_beta_measure": g_beta_measure,
        "test_challenge_metric": challenge_metric,
    }
    class_output_string = "Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}".format(
        ",".join(classes),
        ",".join("{:.3f}".format(x) for x in auroc_classes),
        ",".join("{:.3f}".format(x) for x in auprc_classes),
        ",".join("{:.3f}".format(x) for x in f_measure_classes),
    )

    print(log)
    return log, class_output_string, models

# %%
for dc_idx, data_config in enumerate(data_configs):
    print(f"Experiment {dc_idx}")
    with ElapsedTimer() as t:
        log, class_output_string, models = train_experiment(data_config)

        with open(f"cinc-2020-redux/v{dc_idx}_test_results.json", "w") as f:
            json.dump(log, f)
        with open(f"cinc-2020-redux/v{dc_idx}_test_class_labelwise.csv", "w") as f:
            f.write(class_output_string)
        with open(f"cinc-2020-redux/v{dc_idx}_models.pkl", "wb") as f:
            pickle.dump(models, f)
            
    print(f"Experiment {dc_idx} Took {t.duration:.2f}s")
# Out:
# Experiment 0
# Training 1st degree av block classifier...Took 5.21 seconds
# Training atrial fibrillation classifier...Took 5.09 seconds
# Training atrial flutter classifier...Took 4.18 seconds
# Training bradycardia classifier...Took 5.14 seconds
# Training complete right bundle branch block classifier...Took 4.28 seconds
# Training incomplete right bundle branch block classifier...Took 5.04 seconds
# Training left anterior fascicular block classifier...Took 4.96 seconds
# Training left axis deviation classifier...Took 4.99 seconds
# Training left bundle branch block classifier...Took 3.71 seconds
# Training low qrs voltages classifier...Took 3.98 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 5.08 seconds
# Training pacing rhythm classifier...Took 4.60 seconds
# Training premature atrial contraction classifier...Took 4.90 seconds
# Training premature ventricular contractions classifier...Took 4.90 seconds
# Training Prolonged PR interval classifier...Took 5.18 seconds
# Training prolonged qt interval classifier...Took 4.94 seconds
# Training qwave abnormal classifier...Took 4.93 seconds
# Training right axis deviation classifier...Took 5.23 seconds
# Training right bundle branch block classifier...Took 4.26 seconds
# Training sinus arrhythmia classifier...Took 5.25 seconds
# Training sinus bradycardia classifier...Took 5.01 seconds
# Training sinus rhythm classifier...Took 3.92 seconds
# Training sinus tachycardia classifier...Took 4.76 seconds
# Training supraventricular premature beats classifier...Took 4.87 seconds
# Training t wave abnormal classifier...Took 5.29 seconds
# Training t wave inversion classifier...Took 5.16 seconds
# Training ventricular premature beats classifier...Took 5.02 seconds
# {'test_auroc': 0.8876812845999306, 'test_auprc': 0.3910842261862067, 'test_accuracy': 0.30596149385293436, 'test_f_measure': 0.36625663966624517, 'test_f_beta_measure': 0.4222475047334305, 'test_g_beta_measure': 0.22395741871076394, 'test_challenge_metric': 0.43790826495253893}
# Experiment 0 Took 137.70s
# Experiment 1
# Training 1st degree av block classifier...Took 5.42 seconds
# Training atrial fibrillation classifier...Took 5.15 seconds
# Training atrial flutter classifier...Took 4.51 seconds
# Training bradycardia classifier...Took 5.20 seconds
# Training complete right bundle branch block classifier...Took 3.96 seconds
# Training incomplete right bundle branch block classifier...Took 5.17 seconds
# Training left anterior fascicular block classifier...Took 5.22 seconds
# Training left axis deviation classifier...Took 5.07 seconds
# Training left bundle branch block classifier...Took 3.78 seconds
# Training low qrs voltages classifier...Took 4.79 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 5.10 seconds
# Training pacing rhythm classifier...Took 4.88 seconds
# Training premature atrial contraction classifier...Took 5.14 seconds
# Training premature ventricular contractions classifier...Took 4.94 seconds
# Training Prolonged PR interval classifier...Took 4.95 seconds
# Training prolonged qt interval classifier...Took 5.06 seconds
# Training qwave abnormal classifier...Took 4.86 seconds
# Training right axis deviation classifier...Took 5.02 seconds
# Training right bundle branch block classifier...Took 4.00 seconds
# Training sinus arrhythmia classifier...Took 5.16 seconds
# Training sinus bradycardia classifier...Took 2.99 seconds
# Training sinus rhythm classifier...Took 5.18 seconds
# Training sinus tachycardia classifier...Took 5.11 seconds
# Training supraventricular premature beats classifier...Took 5.03 seconds
# Training t wave abnormal classifier...Took 5.17 seconds
# Training t wave inversion classifier...Took 5.31 seconds
# Training ventricular premature beats classifier...Took 5.06 seconds
# {'test_auroc': 0.8820134724628272, 'test_auprc': 0.38175705880729077, 'test_accuracy': 0.3103688239387613, 'test_f_measure': 0.3606061715958993, 'test_f_beta_measure': 0.4109853211233325, 'test_g_beta_measure': 0.21281003838120682, 'test_challenge_metric': 0.4372740687967073}
# Experiment 1 Took 139.05s
# Experiment 2
# Training 1st degree av block classifier...Took 5.31 seconds
# Training atrial fibrillation classifier...Took 5.07 seconds
# Training atrial flutter classifier...Took 5.07 seconds
# Training bradycardia classifier...Took 4.90 seconds
# Training complete right bundle branch block classifier...Took 4.86 seconds
# Training incomplete right bundle branch block classifier...Took 5.08 seconds
# Training left anterior fascicular block classifier...Took 5.08 seconds
# Training left axis deviation classifier...Took 5.17 seconds
# Training left bundle branch block classifier...Took 3.67 seconds
# Training low qrs voltages classifier...Took 4.83 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 5.22 seconds
# Training pacing rhythm classifier...Took 4.95 seconds
# Training premature atrial contraction classifier...Took 5.09 seconds
# Training premature ventricular contractions classifier...Took 5.05 seconds
# Training Prolonged PR interval classifier...Took 4.78 seconds
# Training prolonged qt interval classifier...Took 5.12 seconds
# Training qwave abnormal classifier...Took 5.14 seconds
# Training right axis deviation classifier...Took 4.20 seconds
# Training right bundle branch block classifier...Took 4.87 seconds
# Training sinus arrhythmia classifier...Took 5.06 seconds
# Training sinus bradycardia classifier...Took 5.30 seconds
# Training sinus rhythm classifier...Took 3.35 seconds
# Training sinus tachycardia classifier...Took 3.36 seconds
# Training supraventricular premature beats classifier...Took 5.15 seconds
# Training t wave abnormal classifier...Took 5.31 seconds
# Training t wave inversion classifier...Took 5.18 seconds
# Training ventricular premature beats classifier...Took 5.01 seconds
# {'test_auroc': 0.8903187665466367, 'test_auprc': 0.39752724672383843, 'test_accuracy': 0.29575504523312457, 'test_f_measure': 0.3719089966391282, 'test_f_beta_measure': 0.4278187290645588, 'test_g_beta_measure': 0.22603560016587987, 'test_challenge_metric': 0.4456397391260152}
# Experiment 2 Took 138.93s
# Experiment 3
# Training 1st degree av block classifier...Took 5.10 seconds
# Training atrial fibrillation classifier...Took 5.18 seconds
# Training atrial flutter classifier...Took 5.09 seconds
# Training bradycardia classifier...Took 3.02 seconds
# Training complete right bundle branch block classifier...Took 5.10 seconds
# Training incomplete right bundle branch block classifier...Took 5.09 seconds
# Training left anterior fascicular block classifier...Took 5.05 seconds
# Training left axis deviation classifier...Took 5.04 seconds
# Training left bundle branch block classifier...Took 3.73 seconds
# Training low qrs voltages classifier...Took 4.12 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 5.03 seconds
# Training pacing rhythm classifier...Took 3.03 seconds
# Training premature atrial contraction classifier...Took 5.02 seconds
# Training premature ventricular contractions classifier...Took 4.83 seconds
# Training Prolonged PR interval classifier...Took 5.08 seconds
# Training prolonged qt interval classifier...Took 5.12 seconds
# Training qwave abnormal classifier...Took 4.87 seconds
# Training right axis deviation classifier...Took 3.22 seconds
# Training right bundle branch block classifier...Took 5.08 seconds
# Training sinus arrhythmia classifier...Took 5.01 seconds
# Training sinus bradycardia classifier...Took 5.06 seconds
# Training sinus rhythm classifier...Took 3.91 seconds
# Training sinus tachycardia classifier...Took 4.26 seconds
# Training supraventricular premature beats classifier...Took 5.07 seconds
# Training t wave abnormal classifier...Took 5.00 seconds
# Training t wave inversion classifier...Took 5.13 seconds
# Training ventricular premature beats classifier...Took 5.00 seconds
# {'test_auroc': 0.8940583156207337, 'test_auprc': 0.3912994603078474, 'test_accuracy': 0.32034330781721176, 'test_f_measure': 0.3722295153740061, 'test_f_beta_measure': 0.43128367835746956, 'test_g_beta_measure': 0.2239971720270254, 'test_challenge_metric': 0.44147198739654414}
# Experiment 3 Took 133.99s
# Experiment 4
# Training 1st degree av block classifier...Took 5.08 seconds
# Training atrial fibrillation classifier...Took 5.22 seconds
# Training atrial flutter classifier...Took 4.96 seconds
# Training bradycardia classifier...Took 3.12 seconds
# Training complete right bundle branch block classifier...Took 4.46 seconds
# Training incomplete right bundle branch block classifier...Took 5.25 seconds
# Training left anterior fascicular block classifier...Took 5.18 seconds
# Training left axis deviation classifier...Took 4.26 seconds
# Training left bundle branch block classifier...Took 3.61 seconds
# Training low qrs voltages classifier...Took 4.76 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 4.99 seconds
# Training pacing rhythm classifier...Took 5.05 seconds
# Training premature atrial contraction classifier...Took 5.01 seconds
# Training premature ventricular contractions classifier...Took 4.81 seconds
# Training Prolonged PR interval classifier...Took 4.75 seconds
# Training prolonged qt interval classifier...Took 4.76 seconds
# Training qwave abnormal classifier...Took 4.70 seconds
# Training right axis deviation classifier...Took 4.63 seconds
# Training right bundle branch block classifier...Took 4.25 seconds
# Training sinus arrhythmia classifier...Took 4.99 seconds
# Training sinus bradycardia classifier...Took 2.97 seconds
# Training sinus rhythm classifier...Took 4.39 seconds
# Training sinus tachycardia classifier...Took 3.03 seconds
# Training supraventricular premature beats classifier...Took 5.00 seconds
# Training t wave abnormal classifier...Took 4.95 seconds
# Training t wave inversion classifier...Took 5.21 seconds
# Training ventricular premature beats classifier...Took 4.69 seconds
# {'test_auroc': 0.8892238045178132, 'test_auprc': 0.3892367109181807, 'test_accuracy': 0.29946648109487356, 'test_f_measure': 0.3559005652433745, 'test_f_beta_measure': 0.411817583658995, 'test_g_beta_measure': 0.2149790378349846, 'test_challenge_metric': 0.42461249664442935}
# Experiment 4 Took 130.89s
# Experiment 5
# Training 1st degree av block classifier...Took 4.97 seconds
# Training atrial fibrillation classifier...Took 4.91 seconds
# Training atrial flutter classifier...Took 4.96 seconds
# Training bradycardia classifier...Took 4.88 seconds
# Training complete right bundle branch block classifier...Took 4.95 seconds
# Training incomplete right bundle branch block classifier...Took 5.18 seconds
# Training left anterior fascicular block classifier...Took 5.08 seconds
# Training left axis deviation classifier...Took 5.11 seconds
# Training left bundle branch block classifier...Took 3.67 seconds
# Training low qrs voltages classifier...Took 4.51 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 5.05 seconds
# Training pacing rhythm classifier...Took 4.88 seconds
# Training premature atrial contraction classifier...Took 4.85 seconds
# Training premature ventricular contractions classifier...Took 4.72 seconds
# Training Prolonged PR interval classifier...Took 3.20 seconds
# Training prolonged qt interval classifier...Took 5.10 seconds
# Training qwave abnormal classifier...Took 4.80 seconds
# Training right axis deviation classifier...Took 4.91 seconds
# Training right bundle branch block classifier...Took 4.95 seconds
# Training sinus arrhythmia classifier...Took 5.13 seconds
# Training sinus bradycardia classifier...Took 5.10 seconds
# Training sinus rhythm classifier...Took 3.99 seconds
# Training sinus tachycardia classifier...Took 4.32 seconds
# Training supraventricular premature beats classifier...Took 4.97 seconds
# Training t wave abnormal classifier...Took 5.16 seconds
# Training t wave inversion classifier...Took 5.08 seconds
# Training ventricular premature beats classifier...Took 4.95 seconds
# {'test_auroc': 0.8817876662009935, 'test_auprc': 0.38715182092479905, 'test_accuracy': 0.31268847135235445, 'test_f_measure': 0.3710566565754639, 'test_f_beta_measure': 0.42564847949773804, 'test_g_beta_measure': 0.2240819579128762, 'test_challenge_metric': 0.44375629925907034}
# Experiment 5 Took 136.03s
# Experiment 6
# Training 1st degree av block classifier...Took 5.04 seconds
# Training atrial fibrillation classifier...Took 4.43 seconds
# Training atrial flutter classifier...Took 5.11 seconds
# Training bradycardia classifier...Took 5.03 seconds
# Training complete right bundle branch block classifier...Took 4.98 seconds
# Training incomplete right bundle branch block classifier...Took 5.10 seconds
# Training left anterior fascicular block classifier...Took 4.99 seconds
# Training left axis deviation classifier...Took 5.14 seconds
# Training left bundle branch block classifier...Took 3.28 seconds
# Training low qrs voltages classifier...Took 4.47 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 5.00 seconds
# Training pacing rhythm classifier...Took 4.85 seconds
# Training premature atrial contraction classifier...Took 5.10 seconds
# Training premature ventricular contractions classifier...Took 3.20 seconds
# Training Prolonged PR interval classifier...Took 2.92 seconds
# Training prolonged qt interval classifier...Took 5.13 seconds
# Training qwave abnormal classifier...Took 4.83 seconds
# Training right axis deviation classifier...Took 5.05 seconds
# Training right bundle branch block classifier...Took 5.06 seconds
# Training sinus arrhythmia classifier...Took 4.11 seconds
# Training sinus bradycardia classifier...Took 4.77 seconds
# Training sinus rhythm classifier...Took 3.82 seconds
# Training sinus tachycardia classifier...Took 4.93 seconds
# Training supraventricular premature beats classifier...Took 5.14 seconds
# Training t wave abnormal classifier...Took 5.22 seconds
# Training t wave inversion classifier...Took 5.10 seconds
# Training ventricular premature beats classifier...Took 3.11 seconds
# {'test_auroc': 0.8873151123193216, 'test_auprc': 0.3972912127065927, 'test_accuracy': 0.3048016701461378, 'test_f_measure': 0.36246321786325114, 'test_f_beta_measure': 0.4120658041887842, 'test_g_beta_measure': 0.2179402274269511, 'test_challenge_metric': 0.43850459414166026}
# Experiment 6 Took 132.45s
# Experiment 7
# Training 1st degree av block classifier...Took 5.22 seconds
# Training atrial fibrillation classifier...Took 5.01 seconds
# Training atrial flutter classifier...Took 2.77 seconds
# Training bradycardia classifier...Took 5.15 seconds
# Training complete right bundle branch block classifier...Took 4.74 seconds
# Training incomplete right bundle branch block classifier...Took 5.21 seconds
# Training left anterior fascicular block classifier...Took 3.76 seconds
# Training left axis deviation classifier...Took 4.95 seconds
# Training left bundle branch block classifier...Took 3.78 seconds
# Training low qrs voltages classifier...Took 4.73 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 5.31 seconds
# Training pacing rhythm classifier...Took 5.05 seconds
# Training premature atrial contraction classifier...Took 5.25 seconds
# Training premature ventricular contractions classifier...Took 4.94 seconds
# Training Prolonged PR interval classifier...Took 5.10 seconds
# Training prolonged qt interval classifier...Took 5.03 seconds
# Training qwave abnormal classifier...Took 5.06 seconds
# Training right axis deviation classifier...Took 4.97 seconds
# Training right bundle branch block classifier...Took 4.61 seconds
# Training sinus arrhythmia classifier...Took 4.01 seconds
# Training sinus bradycardia classifier...Took 5.14 seconds
# Training sinus rhythm classifier...Took 4.27 seconds
# Training sinus tachycardia classifier...Took 3.05 seconds
# Training supraventricular premature beats classifier...Took 4.96 seconds
# Training t wave abnormal classifier...Took 4.62 seconds
# Training t wave inversion classifier...Took 5.01 seconds
# Training ventricular premature beats classifier...Took 4.80 seconds
# {'test_auroc': 0.8840315833298747, 'test_auprc': 0.3977091881005199, 'test_accuracy': 0.30619345859429364, 'test_f_measure': 0.3716110594116415, 'test_f_beta_measure': 0.42501856063306453, 'test_g_beta_measure': 0.2223925870622634, 'test_challenge_metric': 0.4472884267383214}
# Experiment 7 Took 134.26s
# Experiment 8
# Training 1st degree av block classifier...Took 5.04 seconds
# Training atrial fibrillation classifier...Took 5.05 seconds
# Training atrial flutter classifier...Took 5.17 seconds
# Training bradycardia classifier...Took 3.13 seconds
# Training complete right bundle branch block classifier...Took 4.33 seconds
# Training incomplete right bundle branch block classifier...Took 5.23 seconds
# Training left anterior fascicular block classifier...Took 4.72 seconds
# Training left axis deviation classifier...Took 4.86 seconds
# Training left bundle branch block classifier...Took 3.70 seconds
# Training low qrs voltages classifier...Took 4.29 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 5.00 seconds
# Training pacing rhythm classifier...Took 5.05 seconds
# Training premature atrial contraction classifier...Took 5.10 seconds
# Training premature ventricular contractions classifier...Took 5.02 seconds
# Training Prolonged PR interval classifier...Took 5.16 seconds
# Training prolonged qt interval classifier...Took 5.07 seconds
# Training qwave abnormal classifier...Took 5.01 seconds
# Training right axis deviation classifier...Took 5.01 seconds
# Training right bundle branch block classifier...Took 4.27 seconds
# Training sinus arrhythmia classifier...Took 5.12 seconds
# Training sinus bradycardia classifier...Took 2.92 seconds
# Training sinus rhythm classifier...Took 4.33 seconds
# Training sinus tachycardia classifier...Took 5.01 seconds
# Training supraventricular premature beats classifier...Took 5.13 seconds
# Training t wave abnormal classifier...Took 5.09 seconds
# Training t wave inversion classifier...Took 5.05 seconds
# Training ventricular premature beats classifier...Took 4.96 seconds
# {'test_auroc': 0.8930694226243253, 'test_auprc': 0.39611745222267164, 'test_accuracy': 0.3015541637671074, 'test_f_measure': 0.3730842881901437, 'test_f_beta_measure': 0.42490663845797155, 'test_g_beta_measure': 0.22390210504572094, 'test_challenge_metric': 0.4396321904440829}
# Experiment 8 Took 135.57s
# Experiment 9
# Training 1st degree av block classifier...Took 5.08 seconds
# Training atrial fibrillation classifier...Took 5.12 seconds
# Training atrial flutter classifier...Took 5.14 seconds
# Training bradycardia classifier...Took 3.72 seconds
# Training complete right bundle branch block classifier...Took 4.94 seconds
# Training incomplete right bundle branch block classifier...Took 5.25 seconds
# Training left anterior fascicular block classifier...Took 5.08 seconds
# Training left axis deviation classifier...Took 5.05 seconds
# Training left bundle branch block classifier...Took 3.18 seconds
# Training low qrs voltages classifier...Took 4.67 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 4.83 seconds
# Training pacing rhythm classifier...Took 3.79 seconds
# Training premature atrial contraction classifier...Took 4.83 seconds
# Training premature ventricular contractions classifier...Took 4.96 seconds
# Training Prolonged PR interval classifier...Took 5.00 seconds
# Training prolonged qt interval classifier...Took 4.94 seconds
# Training qwave abnormal classifier...Took 4.83 seconds
# Training right axis deviation classifier...Took 4.94 seconds
# Training right bundle branch block classifier...Took 4.90 seconds
# Training sinus arrhythmia classifier...Took 5.21 seconds
# Training sinus bradycardia classifier...Took 5.10 seconds
# Training sinus rhythm classifier...Took 3.79 seconds
# Training sinus tachycardia classifier...Took 4.94 seconds
# Training supraventricular premature beats classifier...Took 4.71 seconds
# Training t wave abnormal classifier...Took 5.04 seconds
# Training t wave inversion classifier...Took 4.13 seconds
# Training ventricular premature beats classifier...Took 4.89 seconds
# {'test_auroc': 0.8901484350146017, 'test_auprc': 0.3874256448789777, 'test_accuracy': 0.30920900023196474, 'test_f_measure': 0.3666342870781291, 'test_f_beta_measure': 0.42308901419647665, 'test_g_beta_measure': 0.21871584182997275, 'test_challenge_metric': 0.4373166429388185}
# Experiment 9 Took 134.93s
# Experiment 10
# Training 1st degree av block classifier...Took 4.41 seconds
# Training atrial fibrillation classifier...Took 5.06 seconds
# Training atrial flutter classifier...Took 4.60 seconds
# Training bradycardia classifier...Took 4.98 seconds
# Training complete right bundle branch block classifier...Took 4.46 seconds
# Training incomplete right bundle branch block classifier...Took 4.02 seconds
# Training left anterior fascicular block classifier...Took 5.13 seconds
# Training left axis deviation classifier...Took 5.06 seconds
# Training left bundle branch block classifier...Took 3.33 seconds
# Training low qrs voltages classifier...Took 4.85 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 5.20 seconds
# Training pacing rhythm classifier...Took 4.20 seconds
# Training premature atrial contraction classifier...Took 4.98 seconds
# Training premature ventricular contractions classifier...Took 4.62 seconds
# Training Prolonged PR interval classifier...Took 5.11 seconds
# Training prolonged qt interval classifier...Took 4.99 seconds
# Training qwave abnormal classifier...Took 4.85 seconds
# Training right axis deviation classifier...Took 5.17 seconds
# Training right bundle branch block classifier...Took 4.43 seconds
# Training sinus arrhythmia classifier...Took 5.09 seconds
# Training sinus bradycardia classifier...Took 5.32 seconds
# Training sinus rhythm classifier...Took 3.92 seconds
# Training sinus tachycardia classifier...Took 5.12 seconds
# Training supraventricular premature beats classifier...Took 5.12 seconds
# Training t wave abnormal classifier...Took 5.23 seconds
# Training t wave inversion classifier...Took 5.15 seconds
# Training ventricular premature beats classifier...Took 4.70 seconds
# {'test_auroc': 0.8846907676598637, 'test_auprc': 0.3925600617875651, 'test_accuracy': 0.30549756437021575, 'test_f_measure': 0.36480464636196014, 'test_f_beta_measure': 0.4179856331327098, 'test_g_beta_measure': 0.22161029682262046, 'test_challenge_metric': 0.438832086769125}
# Experiment 10 Took 135.76s
# Experiment 11
# Training 1st degree av block classifier...Took 5.15 seconds
# Training atrial fibrillation classifier...Took 5.14 seconds
# Training atrial flutter classifier...Took 4.07 seconds
# Training bradycardia classifier...Took 4.50 seconds
# Training complete right bundle branch block classifier...Took 3.78 seconds
# Training incomplete right bundle branch block classifier...Took 3.14 seconds
# Training left anterior fascicular block classifier...Took 5.17 seconds
# Training left axis deviation classifier...Took 5.30 seconds
# Training left bundle branch block classifier...Took 4.51 seconds
# Training low qrs voltages classifier...Took 4.80 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 5.27 seconds
# Training pacing rhythm classifier...Took 4.60 seconds
# Training premature atrial contraction classifier...Took 5.18 seconds
# Training premature ventricular contractions classifier...Took 4.94 seconds
# Training Prolonged PR interval classifier...Took 5.14 seconds
# Training prolonged qt interval classifier...Took 5.28 seconds
# Training qwave abnormal classifier...Took 4.88 seconds
# Training right axis deviation classifier...Took 5.08 seconds
# Training right bundle branch block classifier...Took 3.74 seconds
# Training sinus arrhythmia classifier...Took 5.14 seconds
# Training sinus bradycardia classifier...Took 5.08 seconds
# Training sinus rhythm classifier...Took 3.47 seconds
# Training sinus tachycardia classifier...Took 4.78 seconds
# Training supraventricular premature beats classifier...Took 5.09 seconds
# Training t wave abnormal classifier...Took 5.07 seconds
# Training t wave inversion classifier...Took 5.08 seconds
# Training ventricular premature beats classifier...Took 5.16 seconds
# {'test_auroc': 0.8822535398477047, 'test_auprc': 0.3831010419783294, 'test_accuracy': 0.30967292971468335, 'test_f_measure': 0.363159675481664, 'test_f_beta_measure': 0.41237124461770563, 'test_g_beta_measure': 0.2157998077568459, 'test_challenge_metric': 0.43683198175604643}
# Experiment 11 Took 136.25s
# Experiment 12
# Training 1st degree av block classifier...Took 5.05 seconds
# Training atrial fibrillation classifier...Took 5.18 seconds
# Training atrial flutter classifier...Took 4.19 seconds
# Training bradycardia classifier...Took 3.06 seconds
# Training complete right bundle branch block classifier...Took 3.77 seconds
# Training incomplete right bundle branch block classifier...Took 5.23 seconds
# Training left anterior fascicular block classifier...Took 5.11 seconds
# Training left axis deviation classifier...Took 5.09 seconds
# Training left bundle branch block classifier...Took 3.64 seconds
# Training low qrs voltages classifier...Took 4.87 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 5.17 seconds
# Training pacing rhythm classifier...Took 5.05 seconds
# Training premature atrial contraction classifier...Took 5.06 seconds
# Training premature ventricular contractions classifier...Took 4.97 seconds
# Training Prolonged PR interval classifier...Took 5.33 seconds
# Training prolonged qt interval classifier...Took 5.11 seconds
# Training qwave abnormal classifier...Took 4.86 seconds
# Training right axis deviation classifier...Took 4.10 seconds
# Training right bundle branch block classifier...Took 3.80 seconds
# Training sinus arrhythmia classifier...Took 5.04 seconds
# Training sinus bradycardia classifier...Took 5.05 seconds
# Training sinus rhythm classifier...Took 3.83 seconds
# Training sinus tachycardia classifier...Took 5.07 seconds
# Training supraventricular premature beats classifier...Took 5.04 seconds
# Training t wave abnormal classifier...Took 5.11 seconds
# Training t wave inversion classifier...Took 3.97 seconds
# Training ventricular premature beats classifier...Took 5.07 seconds
# {'test_auroc': 0.8923073026918806, 'test_auprc': 0.39065518285980794, 'test_accuracy': 0.3117606123869172, 'test_f_measure': 0.3679843881025043, 'test_f_beta_measure': 0.4226003004321279, 'test_g_beta_measure': 0.22166212445007819, 'test_challenge_metric': 0.43365482652385345}
# Experiment 12 Took 134.42s
# Experiment 13
# Training 1st degree av block classifier...Took 5.10 seconds
# Training atrial fibrillation classifier...Took 4.27 seconds
# Training atrial flutter classifier...Took 5.19 seconds
# Training bradycardia classifier...Took 3.04 seconds
# Training complete right bundle branch block classifier...Took 4.55 seconds
# Training incomplete right bundle branch block classifier...Took 5.26 seconds
# Training left anterior fascicular block classifier...Took 5.19 seconds
# Training left axis deviation classifier...Took 5.10 seconds
# Training left bundle branch block classifier...Took 4.34 seconds
# Training low qrs voltages classifier...Took 4.82 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 5.10 seconds
# Training pacing rhythm classifier...Took 4.66 seconds
# Training premature atrial contraction classifier...Took 5.10 seconds
# Training premature ventricular contractions classifier...Took 4.50 seconds
# Training Prolonged PR interval classifier...Took 5.24 seconds
# Training prolonged qt interval classifier...Took 5.07 seconds
# Training qwave abnormal classifier...Took 4.94 seconds
# Training right axis deviation classifier...Took 5.28 seconds
# Training right bundle branch block classifier...Took 4.41 seconds
# Training sinus arrhythmia classifier...Took 5.22 seconds
# Training sinus bradycardia classifier...Took 5.21 seconds
# Training sinus rhythm classifier...Took 4.40 seconds
# Training sinus tachycardia classifier...Took 5.12 seconds
# Training supraventricular premature beats classifier...Took 4.98 seconds
# Training t wave abnormal classifier...Took 5.11 seconds
# Training t wave inversion classifier...Took 5.14 seconds
# Training ventricular premature beats classifier...Took 4.66 seconds
# {'test_auroc': 0.8886892895081656, 'test_auprc': 0.3826167219066625, 'test_accuracy': 0.3245186731616794, 'test_f_measure': 0.36402612604617035, 'test_f_beta_measure': 0.41529678869446135, 'test_g_beta_measure': 0.22185351634246384, 'test_challenge_metric': 0.44200061939391505}
# Experiment 13 Took 138.68s
# Experiment 14
# Training 1st degree av block classifier...Took 5.10 seconds
# Training atrial fibrillation classifier...Took 4.72 seconds
# Training atrial flutter classifier...Took 5.09 seconds
# Training bradycardia classifier...Took 5.14 seconds
# Training complete right bundle branch block classifier...Took 4.61 seconds
# Training incomplete right bundle branch block classifier...Took 5.17 seconds
# Training left anterior fascicular block classifier...Took 5.17 seconds
# Training left axis deviation classifier...Took 5.10 seconds
# Training left bundle branch block classifier...Took 3.53 seconds
# Training low qrs voltages classifier...Took 4.33 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 4.97 seconds
# Training pacing rhythm classifier...Took 4.89 seconds
# Training premature atrial contraction classifier...Took 4.96 seconds
# Training premature ventricular contractions classifier...Took 4.86 seconds
# Training Prolonged PR interval classifier...Took 3.13 seconds
# Training prolonged qt interval classifier...Took 5.12 seconds
# Training qwave abnormal classifier...Took 4.87 seconds
# Training right axis deviation classifier...Took 3.96 seconds
# Training right bundle branch block classifier...Took 4.64 seconds
# Training sinus arrhythmia classifier...Took 3.94 seconds
# Training sinus bradycardia classifier...Took 3.66 seconds
# Training sinus rhythm classifier...Took 4.68 seconds
# Training sinus tachycardia classifier...Took 4.93 seconds
# Training supraventricular premature beats classifier...Took 4.92 seconds
# Training t wave abnormal classifier...Took 3.74 seconds
# Training t wave inversion classifier...Took 4.04 seconds
# Training ventricular premature beats classifier...Took 4.87 seconds
# {'test_auroc': 0.8870316030378514, 'test_auprc': 0.38688272016365177, 'test_accuracy': 0.31129668290419854, 'test_f_measure': 0.36650145655278116, 'test_f_beta_measure': 0.4271444243556197, 'test_g_beta_measure': 0.2225456869737911, 'test_challenge_metric': 0.4293796255421054}
# Experiment 14 Took 131.81s
# Experiment 15
# Training 1st degree av block classifier...Took 4.75 seconds
# Training atrial fibrillation classifier...Took 5.05 seconds
# Training atrial flutter classifier...Took 5.09 seconds
# Training bradycardia classifier...Took 5.12 seconds
# Training complete right bundle branch block classifier...Took 4.74 seconds
# Training incomplete right bundle branch block classifier...Took 4.14 seconds
# Training left anterior fascicular block classifier...Took 5.00 seconds
# Training left axis deviation classifier...Took 5.00 seconds
# Training left bundle branch block classifier...Took 4.23 seconds
# Training low qrs voltages classifier...Took 4.56 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 4.77 seconds
# Training pacing rhythm classifier...Took 4.30 seconds
# Training premature atrial contraction classifier...Took 4.88 seconds
# Training premature ventricular contractions classifier...Took 4.86 seconds
# Training Prolonged PR interval classifier...Took 5.00 seconds
# Training prolonged qt interval classifier...Took 4.98 seconds
# Training qwave abnormal classifier...Took 4.07 seconds
# Training right axis deviation classifier...Took 3.73 seconds
# Training right bundle branch block classifier...Took 4.83 seconds
# Training sinus arrhythmia classifier...Took 4.98 seconds
# Training sinus bradycardia classifier...Took 4.96 seconds
# Training sinus rhythm classifier...Took 3.69 seconds
# Training sinus tachycardia classifier...Took 3.78 seconds
# Training supraventricular premature beats classifier...Took 4.93 seconds
# Training t wave abnormal classifier...Took 5.11 seconds
# Training t wave inversion classifier...Took 4.21 seconds
# Training ventricular premature beats classifier...Took 4.88 seconds
# {'test_auroc': 0.8830338730518533, 'test_auprc': 0.38523562800760053, 'test_accuracy': 0.31315240083507306, 'test_f_measure': 0.35949504091539836, 'test_f_beta_measure': 0.40891460982871225, 'test_g_beta_measure': 0.2134837041001565, 'test_challenge_metric': 0.440287234642356}
# Experiment 15 Took 133.51s
# Experiment 16
# Training 1st degree av block classifier...Took 5.11 seconds
# Training atrial fibrillation classifier...Took 5.20 seconds
# Training atrial flutter classifier...Took 3.44 seconds
# Training bradycardia classifier...Took 3.19 seconds
# Training complete right bundle branch block classifier...Took 4.97 seconds
# Training incomplete right bundle branch block classifier...Took 5.14 seconds
# Training left anterior fascicular block classifier...Took 4.93 seconds
# Training left axis deviation classifier...Took 4.54 seconds
# Training left bundle branch block classifier...Took 3.88 seconds
# Training low qrs voltages classifier...Took 4.80 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 5.09 seconds
# Training pacing rhythm classifier...Took 4.46 seconds
# Training premature atrial contraction classifier...Took 4.86 seconds
# Training premature ventricular contractions classifier...Took 4.88 seconds
# Training Prolonged PR interval classifier...Took 3.03 seconds
# Training prolonged qt interval classifier...Took 5.14 seconds
# Training qwave abnormal classifier...Took 5.05 seconds
# Training right axis deviation classifier...Took 5.13 seconds
# Training right bundle branch block classifier...Took 4.85 seconds
# Training sinus arrhythmia classifier...Took 4.92 seconds
# Training sinus bradycardia classifier...Took 5.24 seconds
# Training sinus rhythm classifier...Took 3.36 seconds
# Training sinus tachycardia classifier...Took 4.06 seconds
# Training supraventricular premature beats classifier...Took 5.04 seconds
# Training t wave abnormal classifier...Took 5.21 seconds
# Training t wave inversion classifier...Took 5.13 seconds
# Training ventricular premature beats classifier...Took 4.95 seconds
# {'test_auroc': 0.8862848088881851, 'test_auprc': 0.39453814600395826, 'test_accuracy': 0.2985386221294363, 'test_f_measure': 0.36778255194258885, 'test_f_beta_measure': 0.42495385888058473, 'test_g_beta_measure': 0.21914887905037492, 'test_challenge_metric': 0.42836204351582563}
# Experiment 16 Took 133.19s
# Experiment 17
# Training 1st degree av block classifier...Took 5.04 seconds
# Training atrial fibrillation classifier...Took 4.97 seconds
# Training atrial flutter classifier...Took 5.18 seconds
# Training bradycardia classifier...Took 3.06 seconds
# Training complete right bundle branch block classifier...Took 4.39 seconds
# Training incomplete right bundle branch block classifier...Took 5.09 seconds
# Training left anterior fascicular block classifier...Took 4.82 seconds
# Training left axis deviation classifier...Took 4.92 seconds
# Training left bundle branch block classifier...Took 4.45 seconds
# Training low qrs voltages classifier...Took 4.20 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 5.09 seconds
# Training pacing rhythm classifier...Took 4.89 seconds
# Training premature atrial contraction classifier...Took 4.84 seconds
# Training premature ventricular contractions classifier...Took 3.15 seconds
# Training Prolonged PR interval classifier...Took 5.02 seconds
# Training prolonged qt interval classifier...Took 5.19 seconds
# Training qwave abnormal classifier...Took 4.91 seconds
# Training right axis deviation classifier...Took 3.63 seconds
# Training right bundle branch block classifier...Took 4.38 seconds
# Training sinus arrhythmia classifier...Took 5.05 seconds
# Training sinus bradycardia classifier...Took 5.07 seconds
# Training sinus rhythm classifier...Took 4.35 seconds
# Training sinus tachycardia classifier...Took 3.05 seconds
# Training supraventricular premature beats classifier...Took 5.04 seconds
# Training t wave abnormal classifier...Took 5.00 seconds
# Training t wave inversion classifier...Took 5.03 seconds
# Training ventricular premature beats classifier...Took 3.21 seconds
# {'test_auroc': 0.8942462711338308, 'test_auprc': 0.39658397507299536, 'test_accuracy': 0.3048016701461378, 'test_f_measure': 0.36506997504913735, 'test_f_beta_measure': 0.4143190501504164, 'test_g_beta_measure': 0.2138965688205883, 'test_challenge_metric': 0.44386530434275207}
# Experiment 17 Took 130.91s
# Experiment 18
# Training 1st degree av block classifier...Took 4.46 seconds
# Training atrial fibrillation classifier...Took 4.81 seconds
# Training atrial flutter classifier...Took 4.93 seconds
# Training bradycardia classifier...Took 2.88 seconds
# Training complete right bundle branch block classifier...Took 4.89 seconds
# Training incomplete right bundle branch block classifier...Took 5.12 seconds
# Training left anterior fascicular block classifier...Took 5.03 seconds
# Training left axis deviation classifier...Took 5.07 seconds
# Training left bundle branch block classifier...Took 3.37 seconds
# Training low qrs voltages classifier...Took 4.27 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 4.97 seconds
# Training pacing rhythm classifier...Took 4.14 seconds
# Training premature atrial contraction classifier...Took 4.93 seconds
# Training premature ventricular contractions classifier...Took 4.60 seconds
# Training Prolonged PR interval classifier...Took 5.29 seconds
# Training prolonged qt interval classifier...Took 5.04 seconds
# Training qwave abnormal classifier...Took 4.85 seconds
# Training right axis deviation classifier...Took 4.97 seconds
# Training right bundle branch block classifier...Took 4.79 seconds
# Training sinus arrhythmia classifier...Took 4.99 seconds
# Training sinus bradycardia classifier...Took 4.93 seconds
# Training sinus rhythm classifier...Took 3.69 seconds
# Training sinus tachycardia classifier...Took 3.75 seconds
# Training supraventricular premature beats classifier...Took 5.02 seconds
# Training t wave abnormal classifier...Took 5.05 seconds
# Training t wave inversion classifier...Took 5.07 seconds
# Training ventricular premature beats classifier...Took 4.58 seconds
# {'test_auroc': 0.888698675878798, 'test_auprc': 0.3865401751250291, 'test_accuracy': 0.306425423335653, 'test_f_measure': 0.360713845343324, 'test_f_beta_measure': 0.41393775556790197, 'test_g_beta_measure': 0.22029994313550197, 'test_challenge_metric': 0.44290935695280687}
# Experiment 18 Took 133.23s
# Experiment 19
# Training 1st degree av block classifier...Took 5.10 seconds
# Training atrial fibrillation classifier...Took 5.09 seconds
# Training atrial flutter classifier...Took 4.94 seconds
# Training bradycardia classifier...Took 3.15 seconds
# Training complete right bundle branch block classifier...Took 3.84 seconds
# Training incomplete right bundle branch block classifier...Took 3.76 seconds
# Training left anterior fascicular block classifier...Took 5.14 seconds
# Training left axis deviation classifier...Took 4.98 seconds
# Training left bundle branch block classifier...Took 4.09 seconds
# Training low qrs voltages classifier...Took 4.67 seconds
# Training nonspecific intraventricular conduction disorder classifier...Took 4.88 seconds
# Training pacing rhythm classifier...Took 4.57 seconds
# Training premature atrial contraction classifier...Took 5.05 seconds
# Training premature ventricular contractions classifier...Took 4.86 seconds
# Training Prolonged PR interval classifier...Took 4.12 seconds
# Training prolonged qt interval classifier...Took 4.93 seconds
# Training qwave abnormal classifier...Took 4.78 seconds
# Training right axis deviation classifier...Took 4.83 seconds
# Training right bundle branch block classifier...Took 3.89 seconds
# Training sinus arrhythmia classifier...Took 5.13 seconds
# Training sinus bradycardia classifier...Took 5.16 seconds
# Training sinus rhythm classifier...Took 3.67 seconds
# Training sinus tachycardia classifier...Took 3.73 seconds
# Training supraventricular premature beats classifier...Took 5.08 seconds
# Training t wave abnormal classifier...Took 4.72 seconds
# Training t wave inversion classifier...Took 3.86 seconds
# Training ventricular premature beats classifier...Took 4.83 seconds
# {'test_auroc': 0.8902500114527302, 'test_auprc': 0.3967897160524608, 'test_accuracy': 0.3022500579911853, 'test_f_measure': 0.37712042127147133, 'test_f_beta_measure': 0.43243876265759357, 'test_g_beta_measure': 0.23197575885697908, 'test_challenge_metric': 0.4598863660842612}
# Experiment 19 Took 129.54s
